# %%
# Build a simple webpage that displays text as shown in the below  image?
ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=<device-width>, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
            <b>This text will be bolded.</b> <br>
            <i>This text will be italic</i> <br>
            <ins>This text will be underlined</ins> <br>
            <mark> This text will be highlighted</mark> <br>
            This is normal text <sup>This is superscripted</sup>This is normal again <br>
            This is normal text <sub>This is subscripted</sub> <br>
            Normal text <small>Small text</small> <br>
            <del>this text will be deleted</del>
</body>
</html>

#Build a simple webpage that helps users navigate different web development-related websites.
 Note:On clicking the hyperlink the web pages should open in a new tab. Below is a reference image.

ANS:

 <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=<device-width>, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <head><big><b>Navigate Me:</b></big></head> <br>
    <br>
    <div>
       Take me to <a href="https://pwskills.com" target="blank"> pw skills</a> to buy a course.
    </div><br>
    <div>
        Take me to <a href="https://mdndocs.com" target="blank"> MDN docs</a> to know more about Web Development.
     </div><br>
<div>
    Take me to <a href="https://pwskillslab.com" target="blank"> PW Skills Lab</a> to practice live coding.
 </div>
</body>
</html>

# Build a simple blog web page with 3 pages home, web development, and web design. Each page must
contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
For the home page you can add some information about yourself?
ANS:Do not understand

#Create an ordered list of HTML tags. Each list item must include the tag name and some information about
the tag.
ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <head><b><big>HTML Tags</big></b></head>
    <br>
    <ol type="1">
        <li><b>Bold tag:</b></li>
        Bold tags are used to Bold the content that we have written.<br>
        <br>
        <li><i>Italic Tag:</i></li>
        Italic tags are used to rotate the content at a definite angle.<br>
        <br>
        <li><mark>Highlight tag:</mark></li>
        Highlight tags are used to mark the important content to attain attraction.<br>
        <br>
        <li><ins>Underline Text</ins></li>
        Underline text is used to frame a line under the content.<br>
        <br>
        <li>Brake tag</li>
        Brake tags area used to attain a break after the completion of the line.<br>
        <br>
        <li>Super<sup>script</sup>Tag</li>
        In HTML, the tag defines text as superscript, which appears slightly above the normal line of text and is often rendered in a smaller font, commonly used for footnotes, exponents, and ordinal indicators.<br>
        <br>
        <li>Sub<sub>Script</sub>Tag</li>
        The Subscript tag defines subscript text. Subscript text appears half a character below the normal line, and is sometimes rendered in a smaller font.<br>
        <br>
        <li><del>StrikeThrough</del></li>
        Strikethrough is a formatting style that's often used in technology, computing, programming, and communications. It involves adding a horizontal line through a piece of text to indicate that it has been deleted or marked as no longer relevant.<br>
        <br>
        <li><small>Small TAG</small></li>
        Small tag is used for slight decrease in the size of the text.<br>
        <br>
        <li><Big>Big Tag</Big></li>
        Big tag is used for slight Increase in the size of the text.<br>



    </ol>
</body>
</html>

#Create a description list of full stack web development tech stack, using the <dl> tag. Each term should be
a tech stack name and each description should be a brief explanation of what the tech stack is used for.
ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <HEAD><B><BIG>FULL STACK WEB DEVELOPMENT TECH STACK HTML</BIG></B></HEAD>
    <p>A tech stack is essentially a collection of tools, technologies, and platforms used to build and deploy software applications, encompassing programming languages, frameworks, databases, and other essential components. </p>
    <DL>
        <li><ins>Programming Languages:</ins></li>
        Languages like JavaScript, Python, Java, or PHP, used to write the code that powers the application.<br>
        <br>
        <li><ins>Frameworks: </ins></li>
        Tools like React, Angular, or Django, that provide a structured way to build applications, often simplifying development.<br>
        <br>
        <li><ins>Databases:</ins></li>
        Systems like MySQL, PostgreSQL, or MongoDB, used to store and manage application data. <br>
        <br>
        <li><ins>Front-end Tools: </ins></li>
        Technologies like HTML, CSS, and JavaScript, used to create the user interface of a web application. <br>
        <br>
        <li><ins>Back-end Tools: </ins></li>
        Technologies like web servers (e.g., Apache, Nginx) and operating systems, used to manage the server-side logic and infrastructure. <br>
        <br>
        <li><ins>APIs</ins></li>
        Application Programming Interfaces allow different software systems to communicate and exchange data. <br>
        <br>
    </DL>
</body>
</html>

# Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
stack, create a table that lists the tech stack name, its primary use cases, and some key features or
benefits. Below is a reference image.
ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <head><b><big><INS>Full stack web development tech stack HTML, CSS, and JS</INS></big></b></head>
    <ol type="1">
        <li><B>HTML</B></li><BR>
        HTML, which stands for HyperText Markup Language, is the standard markup language for creating web pages, defining the structure and content displayed in a web browser. It uses tags and elements to organize content like text, images, and multimedia, serving as the foundation for building websites and web applications.
        <h1><ins>Foundation of the Web</ins></h1>
        HTML is the core language that web browsers use to interpret and display web pages.
        <h2><ins>Structure and Content:</ins></h2>
        It defines the structure of a webpage by using elements and tags, which tell the browser how to display text, images, and other content.
        <h3><ins>Working with Other Technologies:</ins></h3>
        HTML often works in conjunction with CSS (for styling) and JavaScript (for interactivity) to create a complete web page. <BR>
        <br>
        <li><b><BIG>CSS</BIG></b></li><BR>
            Cascading Style Sheets (CSS) is a stylesheet language used to describe the presentation of a document written in HTML or XML (including XML dialects such as SVG, MathML or XHTML). CSS describes how elements should be rendered on screen, on paper, in speech, or on other media.<BR>
                <BR>
            <LI><b><big>JAVA SCRIPT</big></b></LI><BR>
            JavaScript is a versatile, lightweight programming language primarily used to create dynamic and interactive content for websites, allowing for features like animations, user interactions, and dynamic updates without requiring page reloads.
            <table border="5">
                <ol type="A">
                    <th><B>HTML</B></th>
                <table border="1">
                    <th>Primary Use Cases</th>
                    <th>Key features/Benefits</th>
                    <tr>
                        <td>Building the structure of the web page</td>
                        <td>
                            <ul>
<li>Simple and easy to learn</li>
<li>Compatible with all web browsers</li>
<li>Allows for semantic markup</li>

                            </ul>
                        </td>



                    </tr>











                </ol>


                </table>




            </table>








    </ol>
    <table border="5">
        <th><b><big>CSS</big></b></th>
    </table>
    <table border="1">
        <th>Primary use cases</th>
        <th>Key features/Benefits</th>
            <tr>
                <td>
                    Styling and layout of web pages
                   <td>
                    <ul>
                        <li>Allows for separation of content and presentation</li>
                        <li>Enables responsive design</li>
                        <li>Offers a wide range of styling option</li>



                    </ul>








                   </td>


                </td>





            </tr>







        </ul>
    </table>
    <table border="5">
        <ol type="A">
            <th><B>JAVA SCRIPT</B></th>
        <table border="1">
            <th>Primary Use Cases</th>
            <th>Key features/Benefits</th>
            <tr>
                <td>To add dynamic and interactive elements
                     to web pages and applications</td>
                <td>
                    <ul>
<li>Dynamic typing</li>
<li>Object-oriented programming</li>
<li>Asynchronous processing</li>

                    </ul>
                </td>



            </tr>











        </ol>


        </table>




    </table>








</ol>
</body>
</html>

#Build a complex nested list structure representing a multi-level table of contents. Use unordered lists
(<ul>) and list items (<li>) with inline-block styling to create a structured layout. Apply formatting tags to
enhance the presentation of list items.

ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <head>
        <h1>Table of Content</h1>
        <br>
        <ul>
            <li><ins>Part 1: Introduction</ins></li>
            <li><ins>Part 2: Getting Started</ins></li>
            <ul type="circle">
                <li><ins>2.1 Installing the Software</ins></li>
                <li><ins>2.2 Creating a new Project</ins></li>
                <ul type="square">
                    <li><ins>2.2.1 Project Template</ins></li>
                    <li><ins>2.2.2 Customizing Settings</ins></li>
            <ul type="circle">
                <li><ins>2.3 Exploring the interface</ins></li>
                <ul type="square">
                    <li><ins>2.3.1 Toolbar Features</ins></li>
                    <li><ins>2.3.2 Panel Layout</ins></li>
                    <ul type="square">
                        <Li><ins>2.3.2.1 Docking Panels</ins></Li>
                        <li><ins>2.3.2.2 Tabbed Interface</ins></li>


                    </ul>

                </ul>

            </ul>

                </ul>
            </ul>
        </ul>
    </head>
</body>
<body>
    <ul>
        <li><ins>Part 3: Advanced Topics</ins></li>
        <ul type="circle">
            <li><ins>3.1 Working with plugins</ins></li>
            <ul type="square">
                <li><ins>3.1.1 Installing Plughins</ins></li>
                <li><ins>3.1.2 Plughin Configuration</ins></li>
        <ul type="circle">
            <li><ins>3.2 customizing the UI</ins></li>
            <UL type="square">
                <li><ins>3.2.1 Changing Themes</ins></li>
                <li><ins>3.2.2 Configuring Shortcuts</ins></li>
        <ul type="circle">
            <li><ins>3.3 Optimizing Performance</ins></li>
            <ul type="square">
                <li><ins>3.3.1 Caching Strategies</ins></li>
                <li><ins>3.3.2 Resource Minifications</ins></li>
            </ul>
            <ul>
                <li><ins>Part 4: Conclusion</ins></li>
            </ul>

        </ul>

            </UL>

        </ul>

            </ul>

        </ul>
    </ul>
</body>
</html>

#Create a table to display a conference schedule. Each row corresponds to a time slot, and each column
corresponds to a room. Some time slots might have multiple sessions running simultaneously in different
rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.
(use table attribute “cellpadding”  to give extra padding in each table cell ).

ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <table border="1">
        <h1>Conference Room</h1>
        <th>Time</th>
        <th>Room 1</th>
        <th>Room 2</th>
        <th>Room 3</th>
        <th>Room 4</th>
        <tr>
            <td rowspan="3">09:00AM-10:00 AM</td>
            <td rowspan="2">Keynote</td>
            <td>Session A</td>
            <td>Session B</td>
            <td rowspan="3">Session C</td>
            <TR>
                <TD>Session D</TD>
                <TD>Session E</TD>

                <tr>
                    <TD>10:30AM-11:30AM</TD>
                <TD colspan="2">Session F</TD>

                </tr>
            </TR>
        </tr>
        <tr>
            <td>12:00 PM-01:00 PM</td>
            <TD Colspan="4">Lunch Break</TD>
            <tr>
                <td rowspan="2">01:00 PM-02:00 PM</td>
                <td>Session G</td>
                <td rowspan="2">Session H</td>
                <td>Session I</td>
                <Td>Session J</Td>
                <TR>
                    <TD>Session K</TD>
                    <td>Session L</td>
                    <td>Session M</td>
                </TR>
            </tr>
        </tr>

    </table>
</body>
</html>
